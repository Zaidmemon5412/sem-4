# %%
import pandas as pd
import numpy as np
df=pd.read_csv("IPL_Matches_2008_2022.csv")
df
# Out:
#           ID        City        Date   Season  MatchNumber  \
# 0    1312200   Ahmedabad  2022-05-29     2022        Final
# 1    1312199   Ahmedabad  2022-05-27     2022  Qualifier 2
# 2    1312198     Kolkata  2022-05-25     2022   Eliminator
# 3    1312197     Kolkata  2022-05-24     2022  Qualifier 1
# 4    1304116      Mumbai  2022-05-22     2022           70
# ..       ...         ...         ...      ...          ...
# 945   335986     Kolkata  2008-04-20  2007/08            4
# 946   335985      Mumbai  2008-04-20  2007/08            5
# 947   335984       Delhi  2008-04-19  2007/08            3
# 948   335983  Chandigarh  2008-04-19  2007/08            2
# 949   335982   Bangalore  2008-04-18  2007/08            1
#
#                            Team1                        Team2  \
# 0               Rajasthan Royals               Gujarat Titans
# 1    Royal Challengers Bangalore             Rajasthan Royals
# 2    Royal Challengers Bangalore         Lucknow Super Giants
# 3               Rajasthan Royals               Gujarat Titans
# 4            Sunrisers Hyderabad                 Punjab Kings
# ..                           ...                          ...
# 945        Kolkata Knight Riders              Deccan Chargers
# 946               Mumbai Indians  Royal Challengers Bangalore
# 947             Delhi Daredevils             Rajasthan Royals
# 948              Kings XI Punjab          Chennai Super Kings
# 949  Royal Challengers Bangalore        Kolkata Knight Riders
#
#                                           Venue                   TossWinner  \
# 0              Narendra Modi Stadium, Ahmedabad             Rajasthan Royals
# 1              Narendra Modi Stadium, Ahmedabad             Rajasthan Royals
# 2                         Eden Gardens, Kolkata         Lucknow Super Giants
# 3                         Eden Gardens, Kolkata               Gujarat Titans
# 4                      Wankhede Stadium, Mumbai          Sunrisers Hyderabad
# ..                                          ...                          ...
# 945                                Eden Gardens              Deccan Chargers
# 946                            Wankhede Stadium               Mumbai Indians
# 947                            Feroz Shah Kotla             Rajasthan Royals
# 948  Punjab Cricket Association Stadium, Mohali          Chennai Super Kings
# 949                       M Chinnaswamy Stadium  Royal Challengers Bangalore
#
#     TossDecision SuperOver                  WinningTeam    WonBy  Margin  \
# 0            bat         N               Gujarat Titans  Wickets     7.0
# 1          field         N             Rajasthan Royals  Wickets     7.0
# 2          field         N  Royal Challengers Bangalore     Runs    14.0
# 3          field         N               Gujarat Titans  Wickets     7.0
# 4            bat         N                 Punjab Kings  Wickets     5.0
# ..           ...       ...                          ...      ...     ...
# 945          bat         N        Kolkata Knight Riders  Wickets     5.0
# 946          bat         N  Royal Challengers Bangalore  Wickets     5.0
# 947          bat         N             Delhi Daredevils  Wickets     9.0
# 948          bat         N          Chennai Super Kings     Runs    33.0
# 949        field         N        Kolkata Knight Riders     Runs   140.0
#
#     method Player_of_Match                                       Team1Players  \
# 0      NaN       HH Pandya  ['YBK Jaiswal', 'JC Buttler', 'SV Samson', 'D ...
# 1      NaN      JC Buttler  ['V Kohli', 'F du Plessis', 'RM Patidar', 'GJ ...
# 2      NaN      RM Patidar  ['V Kohli', 'F du Plessis', 'RM Patidar', 'GJ ...
# 3      NaN       DA Miller  ['YBK Jaiswal', 'JC Buttler', 'SV Samson', 'D ...
# 4      NaN   Harpreet Brar  ['PK Garg', 'Abhishek Sharma', 'RA Tripathi', ...
# ..     ...             ...                                                ...
# 945    NaN       DJ Hussey  ['WP Saha', 'BB McCullum', 'RT Ponting', 'SC G...
# 946    NaN      MV Boucher  ['L Ronchi', 'ST Jayasuriya', 'DJ Thornely', '...
# 947    NaN     MF Maharoof  ['G Gambhir', 'V Sehwag', 'S Dhawan', 'MK Tiwa...
# 948    NaN      MEK Hussey  ['K Goel', 'JR Hopes', 'KC Sangakkara', 'Yuvra...
# 949    NaN     BB McCullum  ['R Dravid', 'W Jaffer', 'V Kohli', 'JH Kallis...
#
#                                           Team2Players        Umpire1  \
# 0    ['WP Saha', 'Shubman Gill', 'MS Wade', 'HH Pan...    CB Gaffaney
# 1    ['YBK Jaiswal', 'JC Buttler', 'SV Samson', 'D ...    CB Gaffaney
# 2    ['Q de Kock', 'KL Rahul', 'M Vohra', 'DJ Hooda...  J Madanagopal
# 3    ['WP Saha', 'Shubman Gill', 'MS Wade', 'HH Pan...   BNJ Oxenford
# 4    ['JM Bairstow', 'S Dhawan', 'M Shahrukh Khan',...   AK Chaudhary
# ..                                                 ...            ...
# 945  ['AC Gilchrist', 'Y Venugopal Rao', 'VVS Laxma...      BF Bowden
# 946  ['S Chanderpaul', 'R Dravid', 'LRPL Taylor', '...       SJ Davis
# 947  ['T Kohli', 'YK Pathan', 'SR Watson', 'M Kaif'...      Aleem Dar
# 948  ['PA Patel', 'ML Hayden', 'MEK Hussey', 'MS Dh...      MR Benson
# 949  ['SC Ganguly', 'BB McCullum', 'RT Ponting', 'D...      Asad Rauf
#
#             Umpire2
# 0       Nitin Menon
# 1       Nitin Menon
# 2          MA Gough
# 3         VK Sharma
# 4     NA Patwardhan
# ..              ...
# 945     K Hariharan
# 946       DJ Harper
# 947  GA Pratapkumar
# 948      SL Shastri
# 949     RE Koertzen
#
# [950 rows x 20 columns]

# %%
df.columns
# Out:
# Index(['ID', 'City', 'Date', 'Season', 'MatchNumber', 'Team1', 'Team2',
#        'Venue', 'TossWinner', 'TossDecision', 'SuperOver', 'WinningTeam',
#        'WonBy', 'Margin', 'method', 'Player_of_Match', 'Team1Players',
#        'Team2Players', 'Umpire1', 'Umpire2'],
#       dtype='object')

# %% [markdown]
# ### Season wise team won the matches max

# %%
df.groupby('Season')['WinningTeam'].apply(lambda x:x.value_counts().head(1)).reset_index()
# Out:
#      Season                level_1  WinningTeam
# 0   2007/08       Rajasthan Royals           13
# 1      2009       Delhi Daredevils           10
# 2   2009/10         Mumbai Indians           11
# 3      2011    Chennai Super Kings           11
# 4      2012  Kolkata Knight Riders           12
# 5      2013         Mumbai Indians           13
# 6      2014        Kings XI Punjab           12
# 7      2015         Mumbai Indians           10
# 8      2016    Sunrisers Hyderabad           11
# 9      2017         Mumbai Indians           12
# 10     2018    Chennai Super Kings           11
# 11     2019         Mumbai Indians           11
# 12  2020/21         Mumbai Indians           11
# 13     2021    Chennai Super Kings           11
# 14     2022         Gujarat Titans           12

# %% [markdown]
# ### Nuumber of the unique player man of the match of each winning team in descending order

# %%
df.groupby("WinningTeam")['Player_of_Match'].apply(lambda x:x.nunique()).sort_values(ascending=False).reset_index()
# Out:
#                     WinningTeam  Player_of_Match
# 0         Kolkata Knight Riders               44
# 1                Mumbai Indians               43
# 2               Kings XI Punjab               42
# 3              Rajasthan Royals               41
# 4           Chennai Super Kings               39
# 5              Delhi Daredevils               39
# 6   Royal Challengers Bangalore               36
# 7           Sunrisers Hyderabad               36
# 8               Deccan Chargers               19
# 9                Delhi Capitals               16
# 10                Pune Warriors               11
# 11                 Punjab Kings               10
# 12               Gujarat Titans                9
# 13                Gujarat Lions                7
# 14       Rising Pune Supergiant                7
# 15         Lucknow Super Giants                6
# 16         Kochi Tuskers Kerala                4
# 17      Rising Pune Supergiants                3

# %% [markdown]
# ###  Which team wins the maximum for the individual stadium

# %%
new_df=pd.DataFrame()
new_df["Count"]=df.Venue.value_counts().head(5)

# %%
new_df=new_df.reset_index()
new_df
# Out:
#                                        Venue  Count
# 0                               Eden Gardens     77
# 1                           Wankhede Stadium     73
# 2                      M Chinnaswamy Stadium     65
# 3                           Feroz Shah Kotla     60
# 4  Rajiv Gandhi International Stadium, Uppal     49

# %%
df1=new_df.merge(df,on="Venue",how="inner")

# %%
df1
# Out:
#                                          Venue  Count       ID       City  \
# 0                                 Eden Gardens     77  1178422    Kolkata
# 1                                 Eden Gardens     77  1178418    Kolkata
# 2                                 Eden Gardens     77  1178410    Kolkata
# 3                                 Eden Gardens     77  1178404    Kolkata
# 4                                 Eden Gardens     77  1178401    Kolkata
# ..                                         ...    ...      ...        ...
# 319  Rajiv Gandhi International Stadium, Uppal     49   336024  Hyderabad
# 320  Rajiv Gandhi International Stadium, Uppal     49   336014  Hyderabad
# 321  Rajiv Gandhi International Stadium, Uppal     49   335999  Hyderabad
# 322  Rajiv Gandhi International Stadium, Uppal     49   335990  Hyderabad
# 323  Rajiv Gandhi International Stadium, Uppal     49   335988  Hyderabad
#
#            Date   Season MatchNumber                        Team1  \
# 0    2019-04-28     2019          47        Kolkata Knight Riders
# 1    2019-04-25     2019          43        Kolkata Knight Riders
# 2    2019-04-19     2019          35  Royal Challengers Bangalore
# 3    2019-04-14     2019          29        Kolkata Knight Riders
# 4    2019-04-12     2019          26        Kolkata Knight Riders
# ..          ...      ...         ...                          ...
# 319  2008-05-18  2007/08          42              Deccan Chargers
# 320  2008-05-11  2007/08          32              Deccan Chargers
# 321  2008-05-01  2007/08          19              Deccan Chargers
# 322  2008-04-24  2007/08           9              Deccan Chargers
# 323  2008-04-22  2007/08           7              Deccan Chargers
#
#                      Team2             TossWinner  ... SuperOver  \
# 0           Mumbai Indians         Mumbai Indians  ...         N
# 1         Rajasthan Royals       Rajasthan Royals  ...         N
# 2    Kolkata Knight Riders  Kolkata Knight Riders  ...         N
# 3      Chennai Super Kings    Chennai Super Kings  ...         N
# 4           Delhi Capitals         Delhi Capitals  ...         N
# ..                     ...                    ...  ...       ...
# 319         Mumbai Indians        Deccan Chargers  ...         N
# 320  Kolkata Knight Riders  Kolkata Knight Riders  ...         N
# 321        Kings XI Punjab        Kings XI Punjab  ...         N
# 322       Rajasthan Royals       Rajasthan Royals  ...         N
# 323       Delhi Daredevils        Deccan Chargers  ...         N
#
#                      WinningTeam    WonBy Margin  method Player_of_Match  \
# 0          Kolkata Knight Riders     Runs   34.0     NaN      AD Russell
# 1               Rajasthan Royals  Wickets    3.0     NaN        VR Aaron
# 2    Royal Challengers Bangalore     Runs   10.0     NaN         V Kohli
# 3            Chennai Super Kings  Wickets    5.0     NaN     Imran Tahir
# 4                 Delhi Capitals  Wickets    7.0     NaN        S Dhawan
# ..                           ...      ...    ...     ...             ...
# 319               Mumbai Indians     Runs   25.0     NaN        DJ Bravo
# 320        Kolkata Knight Riders     Runs   23.0     NaN      SC Ganguly
# 321              Kings XI Punjab  Wickets    7.0     NaN        SE Marsh
# 322             Rajasthan Royals  Wickets    3.0     NaN       YK Pathan
# 323             Delhi Daredevils  Wickets    9.0     NaN        V Sehwag
#
#                                           Team1Players  \
# 0    ['Shubman Gill', 'CA Lynn', 'AD Russell', 'KD ...
# 1    ['CA Lynn', 'Shubman Gill', 'N Rana', 'KD Kart...
# 2    ['PA Patel', 'V Kohli', 'AD Nath', 'MM Ali', '...
# 3    ['CA Lynn', 'SP Narine', 'N Rana', 'RV Uthappa...
# 4    ['JL Denly', 'Shubman Gill', 'RV Uthappa', 'N ...
# ..                                                 ...
# 319  ['AC Gilchrist', 'Shahid Afridi', 'RG Sharma',...
# 320  ['AC Gilchrist', 'HH Gibbs', 'DB Ravi Teja', '...
# 321  ['AC Gilchrist', 'VVS Laxman', 'HH Gibbs', 'RG...
# 322  ['AC Gilchrist', 'VVS Laxman', 'Shahid Afridi'...
# 323  ['AC Gilchrist', 'Y Venugopal Rao', 'VVS Laxma...
#
#                                           Team2Players      Umpire1  \
# 0    ['Q de Kock', 'RG Sharma', 'E Lewis', 'SA Yada...     IJ Gould
# 1    ['AM Rahane', 'SV Samson', 'SPD Smith', 'BA St...  AY Dandekar
# 2    ['CA Lynn', 'SP Narine', 'Shubman Gill', 'RV U...     IJ Gould
# 3    ['SR Watson', 'F du Plessis', 'SK Raina', 'AT ...    CK Nandan
# 4    ['PP Shaw', 'S Dhawan', 'SS Iyer', 'RR Pant', ...    CK Nandan
# ..                                                 ...          ...
# 319  ['ST Jayasuriya', 'SR Tendulkar', 'DJ Thornely...  BR Doctrove
# 320  ['Salman Butt', 'A Chopra', 'SC Ganguly', 'DJ ...    IL Howell
# 321  ['SE Marsh', 'RR Sarwan', 'KC Sangakkara', 'Yu...  BR Doctrove
# 322  ['Kamran Akmal', 'GC Smith', 'YK Pathan', 'SR ...    Asad Rauf
# 323  ['G Gambhir', 'V Sehwag', 'S Dhawan', 'Shoaib ...    IL Howell
#
#          Umpire2
# 0    Nitin Menon
# 1       IJ Gould
# 2    Nitin Menon
# 3      RJ Tucker
# 4       YC Barde
# ..           ...
# 319    DJ Harper
# 320    AM Saheba
# 321    RB Tiffin
# 322    MR Benson
# 323    AM Saheba
#
# [324 rows x 21 columns]

# %%
df1.groupby("Venue")["WinningTeam"].apply(lambda x:x.value_counts().head(1)).reset_index()
# Out:
#                                        Venue                      level_1  \
# 0                               Eden Gardens        Kolkata Knight Riders
# 1                           Feroz Shah Kotla             Delhi Daredevils
# 2                      M Chinnaswamy Stadium  Royal Challengers Bangalore
# 3  Rajiv Gandhi International Stadium, Uppal          Sunrisers Hyderabad
# 4                           Wankhede Stadium               Mumbai Indians
#
#    WinningTeam
# 0           45
# 1           23
# 2           29
# 3           20
# 4           42

# %% [markdown]
#  ### Season wise point Table;2 point for winner else 1 point

# %%
import pandas as pd

matches = pd.read_csv("IPL_Matches_2008_2022.csv")

def matches_played(df, team):
    return df[(df.Team1 == team) | (df.Team2 == team)].shape[0]

def matches_won(df, team):
    return df[df.WinningTeam == team].shape[0]

def matches_no_result(df, team):
    return df[((df.Team1 == team) | (df.Team2 == team)) & (df.WinningTeam.isnull())].shape[0]

def point_table(season):
    df = matches[matches.Season == season]
    new_df = pd.DataFrame()
    new_df['Team Name'] = df.Team1.unique()
    
    new_df["Matches Played"] = new_df["Team Name"].apply(lambda x: matches_played(df, x))
    new_df["Matches Won"] = new_df["Team Name"].apply(lambda x: matches_won(df, x))
    new_df["No Result"] = new_df["Team Name"].apply(lambda x: matches_no_result(df, x))
    
    new_df["Points"] = new_df["Matches Won"]*2 + new_df["No Result"]
    
    new_df.sort_values("Points", ascending=False, inplace=True)
    new_df.set_index("Team Name", inplace=True)
    
    return new_df

#  Apply for all seasons
all_seasons = {}

for season in matches.Season.unique():
    all_seasons[season] = point_table(season)

# Example: print all
for season in all_seasons:
    print("\nSeason:", season)
    print(all_seasons[season])
# Out:
# Season: 2022
#                              Matches Played  Matches Won  No Result  Points
# Team Name
#